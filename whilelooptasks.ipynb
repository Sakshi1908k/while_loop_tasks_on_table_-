# %%
val=eval(input("Enter number for print table of these number"))
i=1
while i <= 10:
    print(val,"*",i,"=",i*val)
    i=i+1
# Out:
# 46 * 1 = 46
# 46 * 2 = 92
# 46 * 3 = 138
# 46 * 4 = 184
# 46 * 5 = 230
# 46 * 6 = 276
# 46 * 7 = 322
# 46 * 8 = 368
# 46 * 9 = 414
# 46 * 10 = 460

# %%
i=10
while i >= 1:
    j=1 
    while j<=10: 
     print(i,"*",j,"=",i*j)
     j=j+1
     print()
    i=i-1
# Out:
# 10 * 1 = 10
#
# 10 * 2 = 20
#
# 10 * 3 = 30
#
# 10 * 4 = 40
#
# 10 * 5 = 50
#
# 10 * 6 = 60
#
# 10 * 7 = 70
#
# 10 * 8 = 80
#
# 10 * 9 = 90
#
# 10 * 10 = 100
#
# 9 * 1 = 9
#
# 9 * 2 = 18
#
# 9 * 3 = 27
#
# 9 * 4 = 36
#
# 9 * 5 = 45
#
# 9 * 6 = 54
#
# 9 * 7 = 63
#
# 9 * 8 = 72
#
# 9 * 9 = 81
#
# 9 * 10 = 90
#
# 8 * 1 = 8
#
# 8 * 2 = 16
#
# 8 * 3 = 24
#
# 8 * 4 = 32
#
# 8 * 5 = 40
#
# 8 * 6 = 48
#
# 8 * 7 = 56
#
# 8 * 8 = 64
#
# 8 * 9 = 72
#
# 8 * 10 = 80
#
# 7 * 1 = 7
#
# 7 * 2 = 14
#
# 7 * 3 = 21
#
# 7 * 4 = 28
#
# 7 * 5 = 35
#
# 7 * 6 = 42
#
# 7 * 7 = 49
#
# 7 * 8 = 56
#
# 7 * 9 = 63
#
# 7 * 10 = 70
#
# 6 * 1 = 6
#
# 6 * 2 = 12
#
# 6 * 3 = 18
#
# 6 * 4 = 24
#
# 6 * 5 = 30
#
# 6 * 6 = 36
#
# 6 * 7 = 42
#
# 6 * 8 = 48
#
# 6 * 9 = 54
#
# 6 * 10 = 60
#
# 5 * 1 = 5
#
# 5 * 2 = 10
#
# 5 * 3 = 15
#
# 5 * 4 = 20
#
# 5 * 5 = 25
#
# 5 * 6 = 30
#
# 5 * 7 = 35
#
# 5 * 8 = 40
#
# 5 * 9 = 45
#
# 5 * 10 = 50
#
# 4 * 1 = 4
#
# 4 * 2 = 8
#
# 4 * 3 = 12
#
# 4 * 4 = 16
#
# 4 * 5 = 20
#
# 4 * 6 = 24
#
# ...

# %%
##WAP to print tables from 1 to 5
i=10
while i<=1:
    j=1
    while j<=10:
        j=j+1
        print(i,"*",j,"=",i*j)
     
        i=i+1

# %%
i=-3
while i <= -5:
    j=-1 
    while j<=-10: 
     print(i,"*",j,"=",i*j)
     j=j-1
     print()
    i=i-1

# %%
i=1
while i <= 50:
    if i % 2 == 0:
      print(i)
      i=i+1
# Out:
#   Cell In[2], line 4
#     print(i)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
i=1
while i<=10:
    print(3,"*",i,"=",i*3)
    i+=1
# Out:
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30

# %%
i=1
while i<=10:
    print(5,"*",i,"=",i*5)
    i=i+1
# Out:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50
